# %% [markdown]
# ### Data Ingestion

# %%
###Document structure
from langchain_core.documents import Document

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is the main text content I am using to create RAG.",
    metadata={"source":"example.txt",
                "pages":1,
              "author":"Rimsha Ameer",
              "date_created":"2025-01-01"
              }
    )
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Rimsha Ameer', 'date_created': '2025-01-01'}, page_content='This is the main text content I am using to create RAG.')

# %%
## create a simple text file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python is a high-level, easy-to-learn programming language created by Guido van Rossum. It is widely used for web development, artificial intelligence, data science, automation, game development, and software applications.

Python is popular because of its simple syntax, readability, and powerful libraries. Beginners can easily understand and write Python code compared to many other programming languages.

Features of Python
Simple and easy syntax
Free and open-source
Platform independent
Supports object-oriented programming
Large collection of libraries
Used in AI, Machine Learning, and Web Development""",
"../data/text_files/machine_learning.txt": """Machine Learning (ML) is a branch of Artificial Intelligence that enables computers to learn patterns from data and make decisions or predictions without being explicitly programmed for every task. In programming basics of machine learning, the focus is on understanding how data is used to train models and how these models improve their performance over time.

The process of machine learning typically starts with collecting data. This data is then cleaned and prepared because real-world data often contains errors, missing values, or irrelevant information. After preprocessing, the data is divided into two parts: training data and testing data. The training data is used to teach the model, while the testing data is used to evaluate how well the model has learned."""
}
for filepath,content in sample_texts.items():
    with open(filepath, 'w' ,encoding="utf-8") as f:
        f.write(content)
        print("sample_texts files created!")
# Out:
# sample_texts files created!
# sample_texts files created!

# %%
### Textloader
#from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level, easy-to-learn programming language created by Guido van Rossum. It is widely used for web development, artificial intelligence, data science, automation, game development, and software applications.\n\nPython is popular because of its simple syntax, readability, and powerful libraries. Beginners can easily understand and write Python code compared to many other programming languages.\n\nFeatures of Python\nSimple and easy syntax\nFree and open-source\nPlatform independent\nSupports object-oriented programming\nLarge collection of libraries\nUsed in AI, Machine Learning, and Web Development')]

# %%
### DirectoryLoader
from langchain_community.document_loaders import DirectoryLoader
### load all text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## pattern to matc files
    loader_cls=TextLoader, ## loader class to use
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)
documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning (ML) is a branch of Artificial Intelligence that enables computers to learn patterns from data and make decisions or predictions without being explicitly programmed for every task. In programming basics of machine learning, the focus is on understanding how data is used to train models and how these models improve their performance over time.\n\nThe process of machine learning typically starts with collecting data. This data is then cleaned and prepared because real-world data often contains errors, missing values, or irrelevant information. After preprocessing, the data is divided into two parts: training data and testing data. The training data is used to teach the model, while the testing data is used to evaluate how well the model has learned.'),
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
### load all text files from the directory
dir_loaders=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## pattern to matc files
    loader_cls=PyMuPDFLoader, ## loader class to use
   ## loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)
pdf_documents=dir_loaders.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-15T04:13:32+00:00', 'source': '..\\data\\pdf\\attention.pdf', 'file_path': '..\\data\\pdf\\attention.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-15T04:13:32+00:00', 'trapped': '', 'modDate': "D:20260515041332+00'00'", 'creationDate': "D:20260515041332+00'00'", 'page': 0}, page_content='Attention Is All You Need\nAbstract\nA novel neural network architecture based solely on attention mechanisms, dispensing with\nrecurrence and convolutions entirely. The Transformer model achieves superior results on\nmachine translation tasks.\nKey Concept: Self-Attention\n• Query (Q), Key (K), Value (V) matrices computed from input\n• Attention(Q,K,V) = softmax(QK^T / sqrt(d_k)) * V\n• Allows each word to attend to every other word in the sequence\nArchitecture\n• E
# ...
